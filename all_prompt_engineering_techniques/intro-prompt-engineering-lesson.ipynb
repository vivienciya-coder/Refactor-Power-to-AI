# %% [markdown]
# # Introduction to Prompt Engineering Tutorial
#
# ## Overview
#
# This tutorial provides a comprehensive introduction to the fundamental concepts of prompt engineering in the context of AI and language models. It is designed to give learners a solid foundation in understanding how to effectively communicate with and leverage large language models through carefully crafted prompts.
#
# ## Motivation
#
# As AI language models become increasingly sophisticated and widely used, the ability to interact with them effectively becomes a crucial skill. Prompt engineering is the key to unlocking the full potential of these models, allowing users to guide AI outputs, improve response quality, and tackle complex tasks. This tutorial aims to equip learners with the essential knowledge and skills to begin their journey in prompt engineering.
#
# ## Key Components
#
# The tutorial covers several key components of prompt engineering:
#
# 1. **Basic Concepts**: An introduction to what prompt engineering is and why it's important.
# 2. **Prompt Structures**: Exploration of different ways to structure prompts for various outcomes.
# 3. **Importance of Prompt Engineering**: Discussion on how prompt engineering impacts AI model performance.
# 4. **Role in AI and Language Models**: Examination of how prompt engineering fits into the broader context of AI applications.
# 5. **Practical Examples**: Hands-on demonstrations of prompt engineering techniques.
#
# ## Method Details
#
# The tutorial employs a mix of theoretical explanations and practical demonstrations to convey the concepts of prompt engineering:
#
# 1. **Setup and Environment**: The lesson begins by setting up the necessary tools, including the OpenAI API and LangChain library. This provides a practical environment for experimenting with prompts.
#
# 2. **Basic Concept Exploration**: Through simple examples, learners are introduced to how different prompts can yield varying responses from the AI model. This illustrates the fundamental principle of prompt engineering.
#
# 3. **Structured Prompts**: The tutorial demonstrates how to create more complex, structured prompts using LangChain's PromptTemplate. This shows how to create reusable prompt structures with variable inputs.
#
# 4. **Comparative Analysis**: By presenting multiple prompts on the same topic, the lesson highlights how subtle changes in prompt structure and wording can significantly affect the AI's output.
#
# 5. **Problem-Solving Application**: The tutorial explores how prompt engineering can be applied to break down complex problems, guiding the AI through a step-by-step reasoning process.
#
# 6. **Limitation Mitigation**: Examples are provided to show how careful prompt design can help overcome some limitations of AI models, such as improving factual accuracy.
#
# Throughout these methods, the tutorial emphasizes the importance of clarity, specificity, and thoughtful design in creating effective prompts.
#
# ## Conclusion
#
# This introductory tutorial on prompt engineering lays the groundwork for understanding and applying this crucial skill in AI interactions. By the end of the lesson, learners will have gained:
#
# 1. A clear understanding of what prompt engineering is and why it's important.
# 2. Insight into how different prompt structures can influence AI outputs.
# 3. Practical experience in crafting prompts for various purposes.
# 4. Awareness of the role prompt engineering plays in enhancing AI model performance.
# 5. A foundation for exploring more advanced prompt engineering techniques.
#
# The skills and knowledge gained from this tutorial will enable learners to more effectively harness the power of AI language models, setting the stage for more advanced applications and explorations in the field of artificial intelligence.

# %% [markdown]
# ## Setup
#
# First, let's import the necessary libraries

# %%
import os
from langchain_openai import ChatOpenAI
import sys
print(sys.executable)
#from langchain.prompts import PromptTemplate

from langchain_core.prompts import PromptTemplate

from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY') # OpenAI API key
# Initialize the language model
llm = ChatOpenAI(model="gpt-4o-mini")
# Out:
# c:\Users\shuai\AppData\Local\Programs\Python\Python312\python.exe
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 12
#       9 from dotenv import load_dotenv
#      10 load_dotenv()
# ---> 12 os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY') # OpenAI API key
#      13 # Initialize the language model
#      14 llm = ChatOpenAI(model="gpt-4o-mini")
#
# File <frozen os>:690, in __setitem__(self, key, value)
#
# File <frozen os>:750, in check_str(value)
#
# TypeError: str expected, not NoneType

# %% [markdown]
# ## Basic Concepts and Importance
#
# Prompt engineering is the practice of designing and optimizing input prompts for language models to generate desired outputs. It's a crucial skill for effectively leveraging AI models in various applications.
#
# Let's explore the concept with a simple example:

# %%
basic_prompt = "Explain the concept of prompt engineering in one sentence."
print(llm.invoke(basic_prompt).content)
# Out:
# Prompt engineering is the art and science of crafting specific and effective instructions – or “prompts” – for AI models like large language models to elicit desired outputs and achieve specific goals.

# %% [markdown]
# Now, let's see how a more structured prompt can yield a more detailed response:

# %%
structured_prompt = PromptTemplate(
    input_variables=["topic"],
    template="Provide a definition of {topic}, explain its importance, and list three key benefits."
)
chain = structured_prompt | llm # Combine the prompt template with the language model
input_variables = {"topic": "prompt engineering"} # Define the input variables
output = chain.invoke(input_variables).content # Invoke the chain with the input variables
print(output)
# Out:
# Okay, let's break down prompt engineering.
#
# **What is Prompt Engineering?**
#
# Prompt engineering is the art and science of crafting effective instructions (prompts) for large language models (LLMs) like GPT-3, LaMDA, or others. It’s about designing the *input* to get the *desired output* from the model.  Essentially, you're learning how to "talk" to these AI systems in a way they understand and respond to most effectively. It goes beyond simply asking a question; it involves carefully structuring your request to guide the model toward generating accurate, relevant, and high-quality responses.  It’s a rapidly evolving field as LLMs become more sophisticated.
#
# Think of it like this: you wouldn't just shout "Write a story!" at a writer and expect a masterpiece. You'd give them a genre, a theme, characters, and perhaps even a starting sentence. Prompt engineering is doing the same thing for an AI.
#
#
# **Why is Prompt Engineering Important?**
#
# Prompt engineering is increasingly vital because:
#
# * **LLMs are sensitive to phrasing:**  Small changes in the wording of a prompt can dramatically alter the output.  A poorly worded prompt can lead to irrelevant, inaccurate, or even nonsensical responses.
# * **LLMs don't "understand" like humans:** They operate based on patterns they've learned from massive datasets. They don't truly *understand* the meaning behind your words.  Therefore, you need to guide them with precise instructions.
# * **Performance depends on the prompt:** The quality of the output from an LLM is directly tied to the quality of the prompt.  Effective prompt engineering unlocks the full potential of these models.
#
#
#
# **Three Key Benefits of Prompt Engineering:**
#
# 1. **Improved Output Quality:**  Well-crafted prompts lead to more accurate, relevant, and coherent responses. By specifying the desired format, tone, and level of detail, you can significantly reduce the chances of the model generating irrelevant or incorrect information.
#
# 2. **Increased Control & Specificity:** Prompt engineering allows you to exert greater control over the model's output. You can guide it to focus on specific aspects of a topic, adopt a particular writing style, or even simulate a specific persona.  This is crucial for tasks like content creation, code generation, and problem-solving.
#
# 3. **Reduced Hallucinations & Errors:** LLMs are prone to "hallucinating" – making up facts or presenting incorrect information confidently.  Strategic prompt engineering, including techniques like providing context, constraints, and verification prompts, can help mitigate this issue and improve the reliability of the generated output.
#
#
#
# **Resources to Learn More:**
#
# * **Learn Prompting:** [https://learnprompting.org/](https://learnprompting.org/) - A fantastic free resource.
# * **Prompt Engineering Guide:** [https://www.promptingguide.ai/](https://www.promptingguide.ai/) - A comprehensive guide.
#
#
# Do you want me to delve deeper into a specific aspect of prompt engineering, such as:
#
# *   Different prompt engineering techniques (e.g., few-shot learning, chain-of-thought prompting)?
# *   Examples of effective prompts for different tasks?
# *   The ethical considerations of prompt engineering?

# %% [markdown]
# ### Importance of Prompt Engineering
#
# Prompt engineering is important because it allows us to:
# 1. Improve the quality and relevance of AI-generated outputs
# 2. Guide language models to perform specific tasks more effectively
# 3. Overcome limitations and biases in AI models
# 4. Customize AI responses for different use cases and audiences
#
# Let's demonstrate how different prompts can lead to different outputs on the same topic:

# %%
prompts = [
    "List 3 applications of AI in healthcare.",
    "Explain how AI is revolutionizing healthcare, with 3 specific examples.",
    "You are a doctor. Describe 3 ways AI has improved your daily work in the hospital."
]

for i, prompt in enumerate(prompts, 1):
    print(f"\nPrompt {i}:")
    print(prompt)
    print("\nResponse:")
    print(llm.invoke(prompt).content)
    print("-" * 50)
# Out:
# Prompt 1:
# List 3 applications of AI in healthcare.
#
# Response:
# Okay, here are 3 applications of AI in healthcare, with a little detail about each:
#
# 1.  **Diagnostic Imaging Analysis:**
#     *   **What it is:** AI, particularly deep learning algorithms, is being used to analyze medical images like X-rays, CT scans, and MRIs.
#     *   **How it’s used:** AI can detect subtle anomalies – like tumors, fractures, or signs of disease – that might be missed by the human eye, especially in large volumes of images. It can also speed up the diagnostic process.
#     *   **Example:** Companies like Google Health and Aidoc are developing AI systems to assist radiologists in detecting breast cancer, lung nodules, and other conditions.
#
#
# 2.  **Personalized Medicine & Drug Discovery:**
#     *   **What it is:** AI analyzes vast amounts of patient data (genomic data, medical history, lifestyle factors) to predict individual risk, tailor treatments, and accelerate drug development.
#     *   **How it’s used:**
#         *   **Risk Prediction:** AI can identify patients at high risk for developing certain diseases (like diabetes or heart disease) based on their data.
#         *   **Treatment Optimization:** It can help doctors choose the most effective treatment for a patient based on their unique characteristics.
#         *   **Drug Discovery:** AI algorithms can sift through millions of compounds to identify potential drug candidates and predict their effectiveness, significantly reducing the time and cost of drug development.
#     *   **Example:**  AI is being used to analyze genomic data to identify genetic mutations that drive cancer growth and to design targeted therapies.
#
#
#
# 3.  **Virtual Assistants & Chatbots:**
#     *   **What it is:** AI-powered chatbots and virtual assistants are used to interact with patients and healthcare providers.
#     *   **How it’s used:**
#         *   **Appointment Scheduling:** Patients can book appointments through chatbots.
#         *   **Symptom Checking:**  Chatbots can ask patients about their symptoms and provide preliminary assessments or advice (often directing them to appropriate care).
#         *   **Medication Reminders:**  They can send reminders to patients to take their medications.
#         *   **Patient Support:**  Some chatbots offer emotional support and answer frequently asked questions.
#     *   **Example:** Many hospitals and healthcare systems are deploying chatbots to handle routine inquiries and improve patient engagement.
#
# ---
#
# Would you like me to:
#
# *   Expand on any of these applications in more detail?
# *   Provide examples of specific companies working in these areas?
# *   Discuss the challenges and ethical considerations surrounding AI in healthcare?
# --------------------------------------------------
#
# Prompt 2:
# Explain how AI is revolutionizing healthcare, with 3 specific examples.
#
# Response:
# Okay, let's break down how Artificial Intelligence (AI) is fundamentally changing healthcare. It’s moving beyond just a buzzword and becoming a core component of diagnostics, treatment, and patient care. Here’s a breakdown with three specific examples:
#
# **1. AI-Powered Diagnostics – Detecting Cancer Earlier & More Accurately**
#
# * **How it’s working:** AI, specifically deep learning algorithms, is being trained on massive datasets of medical images – X-rays, CT scans, MRIs, and pathology slides. These algorithms learn to identify subtle patterns and anomalies that might be missed by the human eye, especially in early stages of disease.
# * **Specific Example: Google’s LYNA (Lymph Node Assistant)** – LYNA is an AI system designed to detect metastatic breast cancer in lymph node biopsies.  Human pathologists often spend a significant amount of time manually examining these slides. LYNA analyzes the images and highlights areas of concern, dramatically reducing the time pathologists spend on this task and increasing the accuracy of identifying cancerous cells. Studies have shown LYNA can improve detection rates by up to 25% compared to traditional methods.
# * **Revolutionary Impact:** This isn’t just about speed; it’s about *earlier detection*.  Early cancer detection dramatically improves treatment outcomes and survival rates.  AI is also being used to diagnose other cancers like lung cancer, skin cancer, and prostate cancer with increasing accuracy.
#
#
# **2. Personalized Treatment Plans – Precision Medicine Driven by AI**
#
# * **How it’s working:** AI analyzes a patient’s entire medical history – including genetic data, lifestyle factors, lab results, and treatment responses – to predict how they will respond to different therapies. This moves beyond a “one-size-fits-all” approach to medicine.
# * **Specific Example: IBM Watson Oncology** – Watson Oncology analyzes a patient’s medical records and compares them to a vast database of medical literature, clinical trials, and treatment guidelines. It then generates a list of potential treatment options, ranked by probability of success, for oncologists. It doesn’t replace the doctor’s judgment, but it provides a powerful tool for evidence-based decision-making, especially in complex cases.
# * **Revolutionary Impact:** This leads to *personalized medicine*. Patients receive treatments tailored to their specific needs, maximizing effectiveness and minimizing side effects. It’s particularly impactful in areas like oncology, where treatment options are complex and responses vary greatly.
#
#
# **3. Robotic Assistance & Remote Patient Monitoring – Improving Efficiency & Access**
#
# * **How it’s working:** AI is powering robots and software that automate tasks, assist surgeons, and monitor patients remotely.
# * **Specific Example:  Moxi by Orbita** – Moxi is a mobile robot that assists nurses in hospitals. It delivers medications, lab samples, and supplies to nurses, freeing them up to spend more time directly with patients. It also uses AI to track nurse movements and optimize workflows, improving hospital efficiency.
# * **Revolutionary Impact:** This improves *operational efficiency* within hospitals, reduces nurse burnout, and allows them to focus on patient care.  Furthermore, remote patient monitoring systems, often incorporating AI, allow for continuous tracking of vital signs and early detection of potential problems, especially for patients with chronic conditions, improving access to care, particularly in rural areas.
#
# ---
#
# **Important Note:** AI in healthcare is still evolving. There are challenges related to data privacy, algorithm bias, and the need for human oversight. However, the potential for AI to transform healthcare is undeniable, and these examples represent just the beginning of a revolution.
#
# Do you want me to delve deeper into a specific aspect of this, such as:
#
# *   The ethical considerations of AI in healthcare?
# *   Specific AI techniques used (e.g., deep learning, natural language processing)?
# *   The potential impact of AI on a particular medical specialty (e.g., cardiology, neurology)?
# --------------------------------------------------
#
# Prompt 3:
# You are a doctor. Describe 3 ways AI has improved your daily work in the hospital.
#
# Response:
# Okay, let’s talk about how Artificial Intelligence is actually making a real difference in my day-to-day work here at St. Jude’s. It’s not about replacing doctors – far from it – but it’s absolutely augmenting our abilities and streamlining processes in ways I never thought possible just a few years ago. Here are three specific ways AI is impacting my practice:
#
# **1. Rapid Diagnostic Support – The “Second Opinion” Engine:**
#
# Honestly, this is probably the biggest game-changer. We use a system called “Clarity” – it’s a sophisticated AI platform – that analyzes medical images like X-rays, CT scans, and MRIs.  Now, I’m not saying it’s giving me a definitive diagnosis on its own. Instead, it’s providing a *highly detailed second opinion* and flagging potential areas of concern that I might have missed, especially in complex cases.
#
# For example, yesterday, I was reviewing a chest X-ray of a patient with shortness of breath. Clarity immediately highlighted a subtle, small nodule in the lower lobe that I hadn't initially picked up on.  It provided a confidence score for its detection and suggested further investigation – a follow-up CT scan.  This didn’t replace my assessment, but it absolutely prompted me to delve deeper and ultimately led to a much earlier diagnosis of early-stage lung cancer.  It’s dramatically reduced the risk of overlooking something critical, particularly with the sheer volume of images we’re reviewing daily.
#
#
# **2. Automated Chart Summarization & Prioritization:**
#
# Let’s be honest, charting is a massive time sink.  Before AI, I’d spend a significant portion of my morning just sifting through patient histories, lab results, and medication lists to get a complete picture. We now use an AI-powered system called “MediFlow” that automatically summarizes patient charts, pulling together relevant information and highlighting key changes.
#
# It’s essentially creating a concise, prioritized overview of a patient’s condition.  It flags critical lab values that are outside the normal range, alerts me to new medication orders, and even pulls together relevant notes from different specialists. This allows me to spend less time wrestling with paperwork and more time actually *talking* to my patients and formulating a treatment plan. It’s significantly improved my efficiency and reduced the risk of overlooking important details buried in lengthy charts.
#
# **3. Predictive Analytics for Patient Risk Stratification:**
#
# This is a newer application, but it’s incredibly powerful. We’re using an AI model – developed by a research team here – that analyzes a patient’s entire medical record – demographics, past diagnoses, lab results, medications, even social determinants of health – to predict their risk of developing complications like sepsis, readmission, or adverse drug events.
#
# It doesn’t tell me *what* to do, but it assigns a risk score to each patient.  For example, if a patient is admitted with pneumonia, the AI might flag them as having a higher-than-average risk of developing sepsis. This prompts me to implement more intensive monitoring, adjust their medication regimen proactively, and ensure they’re receiving the most appropriate level of care. It’s a proactive tool that helps us identify patients who need our attention *before* a crisis occurs.
#
#
#
# ---
#
# **Important Note:** I want to be clear – these AI tools are *assistants*, not replacements for my clinical judgment. They provide data and insights, but the final decision-making always rests with me, based on my experience and understanding of the patient.
#
# Do you have any specific questions about any of these applications, or would you like me to elaborate on a particular aspect?
# --------------------------------------------------

# %% [markdown]
# ## Role in AI and Language Models
#
# Prompt engineering plays a crucial role in enhancing the performance and applicability of AI and language models. It helps in:
#
# 1. Tailoring model outputs to specific needs
# 2. Improving the accuracy and relevance of responses
# 3. Enabling complex task completion
# 4. Reducing biases and improving fairness in AI outputs
#
# Let's explore how prompt engineering can help in overcoming some limitations of language models:

# %%
fact_check_prompt = PromptTemplate(
    input_variables=["statement"],
    template="""Evaluate the following statement for factual accuracy. If it's incorrect, provide the correct information:
    Statement: {statement}
    Evaluation:"""
)

chain = fact_check_prompt | llm
print(chain.invoke("The capital of France is London.").content)
# Out:
# Evaluation: **Incorrect.**
#
# The capital of France is **Paris**, not London. London is the capital of the United Kingdom.
#
# Here's the correct information:
#
# *   **France:** Capital - Paris
# *   **United Kingdom:** Capital - London

# %% [markdown]
# ### Improving Complex Problem-Solving
#
# Prompt engineering can also help in breaking down complex problems and guiding the model through a step-by-step reasoning process:

# %%
problem_solving_prompt = PromptTemplate(
    input_variables=["problem"],
    template="""Solve the following problem step by step:
    Problem: {problem}
    Solution:
    1)"""
)

chain = problem_solving_prompt | llm
print(chain.invoke("Calculate the compound interest on $1000 invested for 5 years at an annual rate of 5%, compounded annually.").content)
# Out:
# Okay, let's break down this compound interest problem step-by-step:
#
# **1) Understand the Formula:**
#
# The formula for compound interest is:
#
# A = P (1 + r/n)^(nt)
#
# Where:
#
# *   A = the future value of the investment/loan, including interest
# *   P = the principal amount (initial investment)
# *   r = the annual interest rate (as a decimal)
# *   n = the number of times that interest is compounded per year
# *   t = the number of years the money is invested or borrowed for
#
# **2) Identify the Values:**
#
# *   P = $1000
# *   r = 5% = 0.05
# *   n = 1 (compounded annually - interest is calculated and added to the principal once per year)
# *   t = 5 years
#
# **3) Plug the Values into the Formula:**
#
# A = 1000 (1 + 0.05/1)^(1*5)
# A = 1000 (1 + 0.05)^5
# A = 1000 (1.05)^5
#
# **4) Calculate (1.05)^5:**
#
# (1.05)^5 = 1.2762815625
#
# **5) Multiply to Find A:**
#
# A = 1000 * 1.2762815625
# A = 1276.2815625
#
# **6) Round to Two Decimal Places (Since we're dealing with money):**
#
# A = $1276.28
#
# **7) Calculate the Compound Interest:**
#
# Compound Interest = A - P
# Compound Interest = $1276.28 - $1000
# Compound Interest = $276.28
#
# **Therefore, the compound interest earned on $1000 invested for 5 years at an annual rate of 5%, compounded annually, is $276.28.**
#
# **Final Answer:**
#
# 1)  A = P (1 + r/n)^(nt)
